# %% [markdown]
# ### basic structure for data and proc

# %% [raw]
# data trail;
# input id name$ salary;
# datalines;
# 101 sugar 2000
# 102 meena 3000
# 103 kumar 4000
# run;
#
# proc print data = trail;
# title my new table;
# run;

# %% [markdown]
# ### now to store in local

# %% [markdown]
# libname demo 'give path name mostly in ubuntu';
# data demo.trail;
# input id name$ salary;
# datalines;
# 101 sugar 2000
# 102 meena 3000
# 103 kumar 4000
# run;
#
# proc print data = trail;
# title my new table;
# run;

# %% [markdown]
# ### now for date field format and informat

# %% [raw]
# libname demo1 'path\..';
# data employee_info;
# input emp_id name$ salary doj;
# informat doj ddmmyy10;
# format doj ddmmyy10;
# datalines;
# 101 sam 2300 12/03/2020
# 102 nidhi 3200 15/04/2021
# 103 mugan 2100 18/05/2024
# ;
# run;
#
# proc print data=employee_info;
# title my new table;
# run;

# %% [markdown]
# ### data joining and scatter plot and regression

# %% [raw]
# data practice1;
# input x y;
# datalines;
# 1 10
# 2 7
# 3 8
# 4 5
# 5 6
# 5.5 7
# 7 2
# 8 3.3
# 9 1.5
# ;
# run;
#
# proc print data = practice1;
#
# proc sgscatter data = practice1;
# plot x*y;
#
# proc reg data=practice1;
# model y=x/clb;

# %% [raw]
# data practice2;
# input x y;
# datalines;
# 8.5 .
# ;
# run;
#
# proc print data=practice2;
# run;

# %% [markdown]
# ## joining code

# %% [raw]
# data practice1;
# set practice1 practice2;
#
# proc print data=practice1;
# run;
#
# proc reg data=practice1;
# model y=x/cli;

# %% [markdown]
# ### fibonacci series

# %% [raw]
# data fibonacci;
# do i=1 to 10;
# fib=sum(fib,lag(fib));
# if i eq 1 then fib=1;
# output;
# end;
# run;
#
# proc print data=fibonacci;
# title fibonacci series;
# run;

# %% [markdown]
# ## basics from intellipaat

# %% [markdown]
# https://www.youtube.com/watch?v=xnnlxTAimOQ

# %% [markdown]
# ## proc sql

# %% [raw]
# data student;
# input name$ sub1 sub2 sub3 gender$;
# sam 67 87 89 male
# anne 34 78 12 female
# julia 90 56 76 female
# ;
# run;
#
# proc print data=student;
# run;
#
# proc sql;
# select * from student;
# quit;

# %% [markdown]
# ## factorial program

# %% [raw]
# data A;
# factorial=1;
# do i=1 to 10;
# factorial=factorial*i;
# output;
# end;

# %% [markdown]
# ### import file and do some calculations
