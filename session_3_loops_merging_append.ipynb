# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## procedures

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# data test;
# infile '/folders/myfolders/pi-10million.txt' lrecl=1000000;
# input digit 1. @@;
# order=_n_;
# run;
#
# proc freq data=test;
# tables digit/chisq;
# run;
